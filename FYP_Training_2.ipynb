# %%
pip install tensorflow keras albumentations opencv-python numpy matplotlib --user
# Out:
# Requirement already satisfied: tensorflow in c:\programdata\anaconda3\envs\py310\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\programdata\anaconda3\envs\py310\lib\site-packages (3.6.0)
# Requirement already satisfied: albumentations in c:\users\fast\appdata\roaming\python\python310\site-packages (2.0.4)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\envs\py310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\py310\lib\site-packages (2.0.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\py310\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\fast\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: rich in c:\programdata\anaconda3\envs\py310\lib\site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in c:\programdata\anaconda3\envs\py310\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: optree in c:\programdata\anaconda3\envs\py310\lib\site-packages (from keras) (0.13.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: PyYAML in c:\programdata\anaconda3\envs\py310\lib\site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\fast\appdata\roaming\python\python310\site-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.23 in c:\users\fast\appdata\roaming\python\python310\site-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\fast\appdata\roaming\python\python310\site-packages (from albumentations) (4.11.0.86)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from albucore==0.0.23->albumentations) (3.12.1)
# Requirement already satisfied: simsimd>=5.9.2 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\fast\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\fast\appdata\roaming\python\python310\site-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\fast\appdata\roaming\python\python310\site-packages (from pydantic>=2.9.2->albumentations) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\envs\py310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import cv2
import tensorflow as tf 
import albumentations as A
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report
import tensorflow.keras.backend as K

# %%
class TeethDataGenerator(Sequence):
    def __init__(self, image_paths, mask_paths, batch_size=8, image_size=(256, 256), augment=True, class_weighting=True, **kwargs):
        super().__init__(**kwargs)
        self.image_paths = image_paths
        self.mask_paths = mask_paths
        self.batch_size = batch_size
        self.image_size = image_size
        self.augment = augment
        self.class_weighting = class_weighting
        self.indexes = np.arange(len(self.image_paths))
        self.on_epoch_end()
        
        self.augmentation = A.Compose([
            A.HorizontalFlip(p=0.5),
            A.VerticalFlip(p=0.5),
            A.RandomBrightnessContrast(p=0.4),
            A.GaussianBlur(p=0.3),
            A.ElasticTransform(alpha=2, sigma=50, alpha_affine=50, p=0.5),
            A.RandomCrop(height=256, width=256, p=0.7)
        ])

    def __len__(self):
        return int(np.floor(len(self.image_paths) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        batch_images = [self.image_paths[k] for k in indexes]
        batch_masks = [self.mask_paths[k] for k in indexes]
        images, masks = self.__data_generation(batch_images, batch_masks)
        return np.array(images), np.array(masks)

    def __data_generation(self, batch_images, batch_masks):
        images, masks = [], [] 
        for img_path, mask_path in zip(batch_images, batch_masks):
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, self.image_size) / 255.0  # Normalize image

            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, self.image_size) / 255.0  # Normalize mask

            # Convert mask to binary: Thresholding (values >= 0.5 become 1, else 0)
            mask = np.where(mask >= 0.5, 1, 0).astype(np.uint8)

            # Mask Check: Ensure only 0 & 1 values
            unique_values = np.unique(mask)
            #print(f"Mask unique values for {mask_path}: {unique_values}")  # Debugging output
            if not np.all(np.isin(unique_values, [0, 1])):
                raise ValueError(f"ERROR: Unexpected mask values in {mask_path}: {unique_values}. Expected only {0, 1}.")


            if self.augment:
                augmented = self.augmentation(image=img, mask=mask)
                img, mask = augmented["image"], augmented["mask"]

            images.append(np.expand_dims(img, axis=-1))
            masks.append(np.expand_dims(mask, axis=-1))

        images, masks = np.array(images), np.array(masks)

        if self.class_weighting:
            mask_weights = np.where(masks > 0.5, 2.0, 1.0)  # Give more weight to teeth pixels
            masks = masks * mask_weights

        return images, masks

    def on_epoch_end(self):
        np.random.shuffle(self.indexes)

# %%
def conv_block(x, num_filters):
    x = layers.Conv2D(num_filters, (3, 3), padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    x = layers.Conv2D(num_filters, (3, 3), padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    
    return x

def upsample_block(x, skip, num_filters):
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, num_filters)
    return x

from tensorflow.keras import layers

def build_unetpp(input_shape=(256, 256, 1)):
    inputs = layers.Input(input_shape)

    c1 = layers.Conv2D(32, (3, 3), padding="same", activation="relu")(inputs)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(64, (3, 3), padding="same", activation="relu")(p1)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(128, (3, 3), padding="same", activation="relu")(p2)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(256, (3, 3), padding="same", activation="relu")(p3)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    c5 = layers.Conv2D(512, (3, 3), padding="same", activation="relu")(p4)

    u4 = layers.UpSampling2D((2,2))(c5)
    u3 = layers.UpSampling2D((2,2))(u4)
    u2 = layers.UpSampling2D((2,2))(u3)
    u1 = layers.UpSampling2D((2,2))(u2)

    outputs = layers.Conv2D(1, (1, 1), activation="sigmoid")(u1)

    return keras.models.Model(inputs, outputs)

# %%
# initialize data generators
train_gen = TeethDataGenerator(train_images, train_masks, batch_size=8, augment=True)
val_gen = TeethDataGenerator(val_images, val_masks, batch_size=8, augment=False)
# Out:
# C:\Users\FAST\AppData\Local\Temp\ipykernel_9440\1125605907.py:18: UserWarning: Argument(s) 'alpha_affine' are not valid for transform ElasticTransform
#   A.ElasticTransform(alpha=2, sigma=50, alpha_affine=50, p=0.5),

# %%
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(tf.cast(y_true, dtype=tf.float32))  # Ensure float32
    y_pred_f = K.flatten(tf.cast(y_pred, dtype=tf.float32))  # Ensure float32
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.9):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    bce = K.binary_crossentropy(y_true, y_pred)
    p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
    focal = alpha * K.pow((1 - p_t), gamma) * bce
    return K.mean(focal)

def combined_loss(y_true, y_pred):
    return 0.5 * dice_loss(y_true, y_pred) + 0.5 * focal_loss(y_true, y_pred)

# %%
# Define Dataset Paths
dataset_path = r"C:\Users\FAST\Desktop\FYP_work-Dental\FYP_work\DecayDataSrc\Teeth_Dataset\augmented"
image_dir = os.path.join(dataset_path, "Images1")
mask_dir = os.path.join(dataset_path, "Masks1")

# Get Sorted Image and Mask Paths
image_paths = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir) if f.endswith('.png')])
mask_paths = sorted([os.path.join(mask_dir, f) for f in os.listdir(mask_dir) if f.endswith('.png')])

# Ensure Correct Image-Mask Pairing
assert len(image_paths) == len(mask_paths), "Mismatch in number of images and masks!"

# Split Dataset: 80% Train, 20% Validation
split = int(0.8 * len(image_paths))
train_images, val_images = image_paths[:split], image_paths[split:]
train_masks, val_masks = mask_paths[:split], mask_paths[split:]

print(f"Training Samples: {len(train_images)}, Validation Samples: {len(val_images)}")
# Out:
# Training Samples: 464, Validation Samples: 116

# %%
model = build_unetpp(input_shape=(256, 256, 1))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=combined_loss, 
              metrics=[dice_coefficient])
checkpoint_path = "unetpp_best_model_2.keras"
callbacks = [
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_dice_coefficient', save_best_only=True, mode='max', verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
]

history = model.fit(train_gen, validation_data=val_gen, epochs=80, callbacks=callbacks)

# Save Final Model
model.save("unetpp_final_trained_2.h5")
# Out:
# Epoch 1/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - dice_coefficient: 0.4927 - loss: 0.3327
# Epoch 1: val_dice_coefficient improved from -inf to 0.56732, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 39s 631ms/step - dice_coefficient: 0.4932 - loss: 0.3324 - val_dice_coefficient: 0.5673 - val_loss: 0.2872 - learning_rate: 1.0000e-04
# Epoch 2/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - dice_coefficient: 0.6423 - loss: 0.2544
# Epoch 2: val_dice_coefficient improved from 0.56732 to 0.79035, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 622ms/step - dice_coefficient: 0.6432 - loss: 0.2540 - val_dice_coefficient: 0.7903 - val_loss: 0.2432 - learning_rate: 1.0000e-04
# Epoch 3/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - dice_coefficient: 0.8098 - loss: 0.1617
# Epoch 3: val_dice_coefficient improved from 0.79035 to 0.85332, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 621ms/step - dice_coefficient: 0.8101 - loss: 0.1613 - val_dice_coefficient: 0.8533 - val_loss: 0.1391 - learning_rate: 1.0000e-04
# Epoch 4/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - dice_coefficient: 0.8517 - loss: 0.0518
# Epoch 4: val_dice_coefficient improved from 0.85332 to 0.85970, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 622ms/step - dice_coefficient: 0.8518 - loss: 0.0519 - val_dice_coefficient: 0.8597 - val_loss: 0.1096 - learning_rate: 1.0000e-04
# Epoch 5/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - dice_coefficient: 0.8582 - loss: 0.0198
# Epoch 5: val_dice_coefficient did not improve from 0.85970
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 621ms/step - dice_coefficient: 0.8582 - loss: 0.0195 - val_dice_coefficient: 0.8520 - val_loss: 0.0709 - learning_rate: 1.0000e-04
# Epoch 6/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - dice_coefficient: 0.8836 - loss: -0.0767
# Epoch 6: val_dice_coefficient improved from 0.85970 to 0.86363, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.8836 - loss: -0.0768 - val_dice_coefficient: 0.8636 - val_loss: 0.0411 - learning_rate: 1.0000e-04
# Epoch 7/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - dice_coefficient: 0.8760 - loss: -0.0956
# Epoch 7: val_dice_coefficient did not improve from 0.86363
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.8760 - loss: -0.0955 - val_dice_coefficient: 0.8580 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 8/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.8716 - loss: -0.1031
# Epoch 8: val_dice_coefficient did not improve from 0.86363
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.8717 - loss: -0.1034 - val_dice_coefficient: 0.8561 - val_loss: 0.0071 - learning_rate: 1.0000e-04
# Epoch 9/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.8796 - loss: -0.1267
# Epoch 9: val_dice_coefficient improved from 0.86363 to 0.86465, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.8797 - loss: -0.1272 - val_dice_coefficient: 0.8647 - val_loss: -0.0162 - learning_rate: 1.0000e-04
# Epoch 10/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.8809 - loss: -0.1369
# Epoch 10: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.8809 - loss: -0.1370 - val_dice_coefficient: 0.8237 - val_loss: 0.1453 - learning_rate: 1.0000e-04
# Epoch 11/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - dice_coefficient: 0.8842 - loss: -0.1441
# Epoch 11: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.8842 - loss: -0.1445 - val_dice_coefficient: 0.8621 - val_loss: 0.0388 - learning_rate: 1.0000e-04
# Epoch 12/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.8800 - loss: -0.1734
# Epoch 12: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.8799 - loss: -0.1735 - val_dice_coefficient: 0.8561 - val_loss: -0.0125 - learning_rate: 1.0000e-04
# Epoch 13/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.8872 - loss: -0.2051
# Epoch 13: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.8871 - loss: -0.2049 - val_dice_coefficient: 0.8477 - val_loss: -0.0050 - learning_rate: 1.0000e-04
# Epoch 14/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.8854 - loss: -0.2202
# Epoch 14: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.8854 - loss: -0.2201 - val_dice_coefficient: 0.8570 - val_loss: -0.0209 - learning_rate: 1.0000e-04
# Epoch 15/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.8770 - loss: -0.1868
# Epoch 15: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.8770 - loss: -0.1871 - val_dice_coefficient: 0.8602 - val_loss: -0.0276 - learning_rate: 1.0000e-04
# Epoch 16/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.8815 - loss: -0.2022
# Epoch 16: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.8817 - loss: -0.2028 - val_dice_coefficient: 0.8430 - val_loss: 0.0155 - learning_rate: 1.0000e-04
# Epoch 17/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.8912 - loss: -0.2400
# Epoch 17: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.8912 - loss: -0.2399 - val_dice_coefficient: 0.8532 - val_loss: -0.0606 - learning_rate: 1.0000e-04
# Epoch 18/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - dice_coefficient: 0.8965 - loss: -0.2913
# Epoch 18: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.8965 - loss: -0.2907 - val_dice_coefficient: 0.8438 - val_loss: -0.0120 - learning_rate: 1.0000e-04
# Epoch 19/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.8915 - loss: -0.2539
# Epoch 19: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.8915 - loss: -0.2540 - val_dice_coefficient: 0.8550 - val_loss: -0.0437 - learning_rate: 1.0000e-04
# Epoch 20/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.8893 - loss: -0.2642
# Epoch 20: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.8895 - loss: -0.2643 - val_dice_coefficient: 0.8546 - val_loss: -0.0355 - learning_rate: 1.0000e-04
# Epoch 21/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9003 - loss: -0.2871
# Epoch 21: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 624ms/step - dice_coefficient: 0.9003 - loss: -0.2871 - val_dice_coefficient: 0.8522 - val_loss: -0.0229 - learning_rate: 1.0000e-04
# Epoch 22/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.8945 - loss: -0.2735
# Epoch 22: val_dice_coefficient did not improve from 0.86465
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.8945 - loss: -0.2734 - val_dice_coefficient: 0.8513 - val_loss: -0.0359 - learning_rate: 1.0000e-04
# Epoch 23/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.9061 - loss: -0.2772
# Epoch 23: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 623ms/step - dice_coefficient: 0.9062 - loss: -0.2778 - val_dice_coefficient: 0.8585 - val_loss: -0.0379 - learning_rate: 5.0000e-05
# Epoch 24/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9125 - loss: -0.3064
# Epoch 24: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.9125 - loss: -0.3061 - val_dice_coefficient: 0.8189 - val_loss: 0.0749 - learning_rate: 5.0000e-05
# Epoch 25/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9147 - loss: -0.3167
# Epoch 25: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.9147 - loss: -0.3165 - val_dice_coefficient: 0.8598 - val_loss: -0.0591 - learning_rate: 5.0000e-05
# Epoch 26/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9006 - loss: -0.2834
# Epoch 26: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9009 - loss: -0.2839 - val_dice_coefficient: 0.8608 - val_loss: -0.0536 - learning_rate: 5.0000e-05
# Epoch 27/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9226 - loss: -0.3321
# Epoch 27: val_dice_coefficient did not improve from 0.86465
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.9225 - loss: -0.3320 - val_dice_coefficient: 0.8566 - val_loss: -0.0444 - learning_rate: 5.0000e-05
# Epoch 28/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9216 - loss: -0.3376
# Epoch 28: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9216 - loss: -0.3377 - val_dice_coefficient: 0.8482 - val_loss: -0.0046 - learning_rate: 2.5000e-05
# Epoch 29/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - dice_coefficient: 0.9227 - loss: -0.3292
# Epoch 29: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.9228 - loss: -0.3293 - val_dice_coefficient: 0.8623 - val_loss: -0.0499 - learning_rate: 2.5000e-05
# Epoch 30/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9182 - loss: -0.3200
# Epoch 30: val_dice_coefficient did not improve from 0.86465
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9182 - loss: -0.3202 - val_dice_coefficient: 0.8619 - val_loss: -0.0633 - learning_rate: 2.5000e-05
# Epoch 31/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9300 - loss: -0.3605
# Epoch 31: val_dice_coefficient improved from 0.86465 to 0.86948, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9300 - loss: -0.3604 - val_dice_coefficient: 0.8695 - val_loss: -0.0655 - learning_rate: 2.5000e-05
# Epoch 32/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9244 - loss: -0.3334
# Epoch 32: val_dice_coefficient improved from 0.86948 to 0.87027, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 37s 630ms/step - dice_coefficient: 0.9244 - loss: -0.3334 - val_dice_coefficient: 0.8703 - val_loss: -0.0830 - learning_rate: 2.5000e-05
# Epoch 33/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9275 - loss: -0.3440
# Epoch 33: val_dice_coefficient did not improve from 0.87027
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9275 - loss: -0.3440 - val_dice_coefficient: 0.8681 - val_loss: -0.0725 - learning_rate: 2.5000e-05
# Epoch 34/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9187 - loss: -0.3173
# Epoch 34: val_dice_coefficient did not improve from 0.87027
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9188 - loss: -0.3176 - val_dice_coefficient: 0.8605 - val_loss: -0.0451 - learning_rate: 2.5000e-05
# Epoch 35/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9184 - loss: -0.3082
# Epoch 35: val_dice_coefficient did not improve from 0.87027
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9186 - loss: -0.3089 - val_dice_coefficient: 0.8661 - val_loss: -0.0542 - learning_rate: 2.5000e-05
# Epoch 36/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9445 - loss: -0.3989
# Epoch 36: val_dice_coefficient did not improve from 0.87027
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9442 - loss: -0.3981 - val_dice_coefficient: 0.8667 - val_loss: -0.0581 - learning_rate: 2.5000e-05
# Epoch 37/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9277 - loss: -0.3401
# Epoch 37: val_dice_coefficient improved from 0.87027 to 0.87214, saving model to unetpp_best_model_2.keras
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9277 - loss: -0.3399 - val_dice_coefficient: 0.8721 - val_loss: -0.0744 - learning_rate: 2.5000e-05
# Epoch 38/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9301 - loss: -0.3561
# Epoch 38: val_dice_coefficient improved from 0.87214 to 0.87265, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9301 - loss: -0.3559 - val_dice_coefficient: 0.8726 - val_loss: -0.0725 - learning_rate: 1.2500e-05
# Epoch 39/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - dice_coefficient: 0.9307 - loss: -0.3437
# Epoch 39: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 41s 624ms/step - dice_coefficient: 0.9307 - loss: -0.3437 - val_dice_coefficient: 0.8675 - val_loss: -0.0576 - learning_rate: 1.2500e-05
# Epoch 40/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9306 - loss: -0.3442
# Epoch 40: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9306 - loss: -0.3442 - val_dice_coefficient: 0.8693 - val_loss: -0.0498 - learning_rate: 1.2500e-05
# Epoch 41/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9329 - loss: -0.3412
# Epoch 41: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9328 - loss: -0.3410 - val_dice_coefficient: 0.8683 - val_loss: -0.0352 - learning_rate: 1.2500e-05
# Epoch 42/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9416 - loss: -0.3656
# Epoch 42: val_dice_coefficient did not improve from 0.87265
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9414 - loss: -0.3650 - val_dice_coefficient: 0.8685 - val_loss: -0.0630 - learning_rate: 1.2500e-05
# Epoch 43/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - dice_coefficient: 0.9286 - loss: -0.3277
# Epoch 43: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9286 - loss: -0.3278 - val_dice_coefficient: 0.8686 - val_loss: -0.0364 - learning_rate: 6.2500e-06
# Epoch 44/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9373 - loss: -0.3477
# Epoch 44: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9373 - loss: -0.3475 - val_dice_coefficient: 0.8704 - val_loss: -0.0567 - learning_rate: 6.2500e-06
# Epoch 45/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9398 - loss: -0.3566
# Epoch 45: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9398 - loss: -0.3565 - val_dice_coefficient: 0.8693 - val_loss: -0.0493 - learning_rate: 6.2500e-06
# Epoch 46/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - dice_coefficient: 0.9467 - loss: -0.3975
# Epoch 46: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9466 - loss: -0.3970 - val_dice_coefficient: 0.8726 - val_loss: -0.0562 - learning_rate: 6.2500e-06
# Epoch 47/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9413 - loss: -0.3755
# Epoch 47: val_dice_coefficient did not improve from 0.87265
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9413 - loss: -0.3755 - val_dice_coefficient: 0.8693 - val_loss: -0.0478 - learning_rate: 6.2500e-06
# Epoch 48/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - dice_coefficient: 0.9303 - loss: -0.3461
# Epoch 48: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9304 - loss: -0.3464 - val_dice_coefficient: 0.8724 - val_loss: -0.0564 - learning_rate: 3.1250e-06
# Epoch 49/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9364 - loss: -0.3460
# Epoch 49: val_dice_coefficient did not improve from 0.87265
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9365 - loss: -0.3463 - val_dice_coefficient: 0.8703 - val_loss: -0.0479 - learning_rate: 3.1250e-06
# Epoch 50/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9415 - loss: -0.3585
# Epoch 50: val_dice_coefficient improved from 0.87265 to 0.87631, saving model to unetpp_best_model_2.keras
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 629ms/step - dice_coefficient: 0.9415 - loss: -0.3584 - val_dice_coefficient: 0.8763 - val_loss: -0.0765 - learning_rate: 3.1250e-06
# Epoch 51/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9432 - loss: -0.3631
# Epoch 51: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9432 - loss: -0.3631 - val_dice_coefficient: 0.8682 - val_loss: -0.0353 - learning_rate: 3.1250e-06
# Epoch 52/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9393 - loss: -0.3573
# Epoch 52: val_dice_coefficient did not improve from 0.87631
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9393 - loss: -0.3573 - val_dice_coefficient: 0.8754 - val_loss: -0.0638 - learning_rate: 3.1250e-06
# Epoch 53/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9372 - loss: -0.3509
# Epoch 53: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9372 - loss: -0.3507 - val_dice_coefficient: 0.8708 - val_loss: -0.0489 - learning_rate: 1.5625e-06
# Epoch 54/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9399 - loss: -0.3525
# Epoch 54: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9399 - loss: -0.3525 - val_dice_coefficient: 0.8720 - val_loss: -0.0487 - learning_rate: 1.5625e-06
# Epoch 55/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9411 - loss: -0.3645
# Epoch 55: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9410 - loss: -0.3644 - val_dice_coefficient: 0.8739 - val_loss: -0.0616 - learning_rate: 1.5625e-06
# Epoch 56/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9304 - loss: -0.3151
# Epoch 56: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9305 - loss: -0.3154 - val_dice_coefficient: 0.8715 - val_loss: -0.0469 - learning_rate: 1.5625e-06
# Epoch 57/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9400 - loss: -0.3559
# Epoch 57: val_dice_coefficient did not improve from 0.87631
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9400 - loss: -0.3559 - val_dice_coefficient: 0.8718 - val_loss: -0.0368 - learning_rate: 1.5625e-06
# Epoch 58/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - dice_coefficient: 0.9404 - loss: -0.3525
# Epoch 58: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 626ms/step - dice_coefficient: 0.9403 - loss: -0.3523 - val_dice_coefficient: 0.8742 - val_loss: -0.0575 - learning_rate: 7.8125e-07
# Epoch 59/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9470 - loss: -0.3953
# Epoch 59: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9469 - loss: -0.3951 - val_dice_coefficient: 0.8747 - val_loss: -0.0621 - learning_rate: 7.8125e-07
# Epoch 60/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - dice_coefficient: 0.9442 - loss: -0.3613
# Epoch 60: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 625ms/step - dice_coefficient: 0.9441 - loss: -0.3612 - val_dice_coefficient: 0.8732 - val_loss: -0.0590 - learning_rate: 7.8125e-07
# Epoch 61/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9234 - loss: -0.3212
# Epoch 61: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9237 - loss: -0.3220 - val_dice_coefficient: 0.8760 - val_loss: -0.0581 - learning_rate: 7.8125e-07
# Epoch 62/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - dice_coefficient: 0.9363 - loss: -0.3357
# Epoch 62: val_dice_coefficient did not improve from 0.87631
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 627ms/step - dice_coefficient: 0.9364 - loss: -0.3361 - val_dice_coefficient: 0.8757 - val_loss: -0.0584 - learning_rate: 7.8125e-07
# Epoch 63/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - dice_coefficient: 0.9413 - loss: -0.3663
# Epoch 63: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 629ms/step - dice_coefficient: 0.9414 - loss: -0.3664 - val_dice_coefficient: 0.8736 - val_loss: -0.0539 - learning_rate: 3.9062e-07
# Epoch 64/80
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - dice_coefficient: 0.9381 - loss: -0.3500
# Epoch 64: val_dice_coefficient did not improve from 0.87631
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 36s 628ms/step - dice_coefficient: 0.9382 - loss: -0.3503 - val_dice_coefficient: 0.8754 - val_loss: -0.0604 - learning_rate: 3.9062e-07
# Epoch 65/80
#  3/58 ━━━━━━━━━━━━━━━━━━━━ 33s 601ms/step - dice_coefficient: 0.9154 - loss: -0.2888
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 11
#       5 checkpoint_path = "unetpp_best_model_2.keras"
#       6 callbacks = [
#       7     ModelCheckpoint(filepath=checkpoint_path, monitor='val_dice_coefficient', save_best_only=True, mode='max', verbose=1),
#       8     ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)
#       9 ]
# ---> 11 history = model.fit(train_gen, validation_data=val_gen, epochs=80, callbacks=callbacks)
#      13 # Save Final Model
#      14 model.save("unetpp_final_trained_2.h5")
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File C:\ProgramData\Anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report

# ✅ Load the trained model
model = load_model("unetpp_best_model_2.keras", custom_objects={
    "dice_coefficient": dice_coefficient,
    "dice_loss": dice_loss,
    "combined_loss": combined_loss
})
print("✅ Model loaded successfully!")

# ✅ Function to preprocess images
def preprocess_image(image_path, target_size=(256, 256)):
    img = tf.keras.preprocessing.image.load_img(image_path, color_mode="grayscale", target_size=target_size)
    img = tf.keras.preprocessing.image.img_to_array(img) / 255.0  # Normalize
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# ✅ Function to preprocess masks (convert to binary labels)
def preprocess_mask(mask_path, target_size=(256, 256)):
    mask = tf.keras.preprocessing.image.load_img(mask_path, color_mode="grayscale", target_size=target_size)
    mask = tf.keras.preprocessing.image.img_to_array(mask) / 255.0  # Normalize
    mask = (mask > 0.5).astype(int)  # Convert to binary mask (0 or 1)
    return mask.flatten()  # Flatten mask to 1D array

# ✅ Load validation images and masks
X_val = np.vstack([preprocess_image(img) for img in val_images])  # Validation images
y_val = np.concatenate([preprocess_mask(mask) for mask in val_masks])  # Validation masks

print("✅ Validation data prepared successfully!")

# ✅ Get predictions
y_pred = model.predict(X_val, batch_size=8)
y_pred = (y_pred > 0.5).astype(int)  # Convert to binary (0 or 1)
y_pred = y_pred.flatten()  # Flatten predictions

print("✅ Predictions generated!")

# ✅ Print classification report
print("\n📊 Classification Report:")
print(classification_report(y_val, y_pred, target_names=["Background", "Teeth"]))
# Out:
# ✅ Model loaded successfully!
# ✅ Validation data prepared successfully!
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step
# ✅ Predictions generated!
#
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#   Background       0.96      0.71      0.82   6130678
#        Teeth       0.42      0.88      0.57   1471498
#
#     accuracy                           0.75   7602176
#    macro avg       0.69      0.80      0.70   7602176
# weighted avg       0.86      0.75      0.77   7602176
